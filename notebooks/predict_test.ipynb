# %%
import os
import sys 
sys.path.append(os.path.relpath('../src/utils'))

import tensorflow as tf

from preprocess_image import load_preprocess_image
from predictions import plot_image_prediction
# Out:
# 2024-03-27 10:55:55.442059: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load model

# %%
model_path = os.path.relpath('../models/model/pretrained_fine_300_ratio.h5')
model = tf.keras.models.load_model(model_path)

# %%
#model.save('models/model/pretrained_fine_300_ratio.h5', save_format='h5')

# %%
test_image_path = os.path.relpath('../data/test_image_001.jpg')
image_array = load_preprocess_image(test_image_path)

# %%
plot_image_prediction(image_array, model)
# Out:
# 1/1 [==============================] - 2s 2s/step
